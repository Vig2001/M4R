# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Research_Project/M4R
# !git config --global user.email "guruvignesh2001@gmail.com"
# !git config --global user.name "Vig2001"
import os

if not os.path.exists('/content/drive/MyDrive/Research_Project/M4R'):
  # !git clone https://Vig2001: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@github.com/Vig2001/M4R.git
else:
  print("Repository Cloned")
# Out:
# /content/drive/MyDrive/Research_Project/M4R
# Repository Cloned

# %%
# !git rm cspan_analysis.ipynb
# Out:
# rm 'cspan_analysis.ipynb'

# %%
# !git config --global user.email "guruvignesh2001@gmail.com"
# !git config --global user.name "Vig2001"

# !git commit -m "remove cspan_analysis.ipynb"
# Out:
# [main f38c97b] remove cspan_analysis.ipynb
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  delete mode 100644 cspan_analysis.ipynb

# %%
# !git remote remove origin

# %%
# !git remote add origin https://Vig2001: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@github.com/Vig2001/M4R.git

# %%
# !git remote -v
# Out:
# origin	https://Vig2001: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@github.com/Vig2001/M4R.git (fetch)
# origin	https://Vig2001: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@github.com/Vig2001/M4R.git (push)

# %%
# !git symbolic-ref refs/remotes/origin/HEAD refs/remotes/origin/main

# %%
# !git branch
# Out:
# * main

# %%
# !git push -u origin main
# Out:
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (2/2), 239 bytes | 21.00 KiB/s, done.
# Total 2 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/Vig2001/M4R.git
#    7825495..f38c97b  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !git add cspan_analysis_google.ipynb
# !git commit -m "add cspan_analysis_google.ipynb"
# !git push -u origin main
# Out:
# fatal: pathspec 'cspan_analysis_google.ipynb' did not match any files
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	csapn_analysis_google.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# Everything up-to-date
